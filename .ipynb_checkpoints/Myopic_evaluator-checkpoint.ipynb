# %%
#Initial Imports
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %% [markdown]
# Part1: Preparing Data

# %%
# Reading CSV file in to a dataframe
file="myopia.csv"
df=pd.read_csv(file)
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
# drop unnecessary data ,Preprocessing data
myopia_data=df.drop("MYOPIC",axis=1)
myopia_data
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0          0    10         34      1      1
# ...

# %%
# Standardize  data in to smaller Values
scaler=StandardScaler()
scaled_data=scaler.fit_transform(myopia_data)

# %% [markdown]
# Part2:Apply Dimensionality Reduction

# %%
# Initialize PCA model
pca = PCA(n_components=0.99)

# %%
pca_transformed_data = pca.fit_transform(scaled_data)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.21177355, 0.15659716, 0.08688023, 0.08301762, 0.07584858,
#        0.06997878, 0.06486986, 0.06377808, 0.05393666, 0.05205566,
#        0.04286506, 0.03839767])

# %% [markdown]
# PCA Explained Variance:
# 1.Explained variance is a statistical measure of how much variation in a dataset can be attributed to each of the principal components (eigenvectors) generated by a PCA.
# 2.This is important because it allows us to rank the components in order of importance, and to focus on the most important ones when interpreting the results of our analysis.
# 3.The larger the variance explained by a principal component, the more important that component is.

# %% [markdown]
# 1.The change in features were reduced from 14 to 12 with 618 samples.
# 2.The outputs of the PCA can be used as input to train a model.
# 3.PCA is a method used to reduce number of variables in your data by extracting important ones from a large pool.
# 4.It reduces the dimension of the data with the aim of retaining as much information as possible (~90% for our data below).
# 5.In other words, this method combines highly correlated variables together to form a smaller number of an artificial set of variables which is called “principal components” that account for most variance in the data.

# %%
# Run t-SNE
tsne = TSNE(learning_rate=50)
transformed_features = tsne.fit_transform(pca_transformed_data)
# Out:
# C:\Users\appua\anaconda3\envs\PythonData\lib\site-packages\sklearn\manifold\_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,

# %%
# Check that dimensions have been reduced 
transformed_features.shape
# Out:
# (618, 2)

# %%
myopia_data["X"] = transformed_features[:,0]
myopia_data["y"] = transformed_features[:,1]
myopia_data["Myopic"] = df["MYOPIC"]
myopia_data.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY          X          y  Myopic
# 0        0    10         34      1      1  -5.826893 -23.647165       1
# 1        1     7         12      1      1 -16.688446   9.479452       0
# 2        0    10         14      0      0  13.739101   2.139052       0
# 3        0     4         37      0      1   0.325433  16.145042       1
# 4        0     4          4      1      0  -3.806811  -9.918604       0

# %%
#Scatter plot using output of t-SNE
plt.scatter(myopia_data["X"], myopia_data["y"])
plt.show()

# %%
# Output of t-SNE in a Scatter plot by color
plt.scatter(myopia_data["X"], myopia_data["y"],c=df['MYOPIC'])
plt.show()

# %%
labels = myopia_data["Myopic"]
labels.value_counts()
# Out:
# 0    537
# 1     81
# Name: Myopic, dtype: int64

# %% [markdown]
# Part 3: Perform a Cluster Analysis with K-means

# %%
df_myopia_pca = pd.DataFrame(data= pca_transformed_data, columns=["principal component 1", "principal component 2",
                                                                "principal component 3","principal component 4",
                                                                "principal component 5","principal component 6",
                                                                 "principal component 7",
                                                                 "principal component 8","principal component 9",
                                                                 "principal component 10","principal component 11",
                                                                  "principal component 12"])
df_myopia_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               0.535503               1.145004              -1.385019
# 1              -0.624706              -1.575786              -0.794253
# 2              -0.933479              -0.717076               0.820150
# 3               0.106354               1.192475              -0.024441
# 4              -0.388503              -2.839655              -0.229767
#
#    principal component 4  principal component 5  principal component 6  \
# 0               0.116006              -3.226691              -1.928459
# 1               1.156287               0.292256               0.349060
# 2              -1.547638               0.173941               0.272783
# 3               1.507469              -2.356836              -0.023139
# 4              -0.622510               0.271458              -0.928956
#
#    principal component 7  principal component 8  principal component 9  \
# ...

# %%
from sklearn.cluster import KMeans
# Finding the best value for k

inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_myopia_pca)
    inertia.append(km.inertia_)

# Creating the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\appua\anaconda3\envs\PythonData\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   "KMeans is known to have a memory leak on Windows "

# %%
df_elbow.head()
# Out:
#    k      inertia
# 0  1  8651.990482
# 1  2  7497.105614
# 2  3  6732.085949
# 3  4  6362.276551
# 4  5  6083.170887

# %%
def get_clusters(k, df_myopia_pca):
    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Train the model
    model.fit(df_myopia_pca)

    # Predict clusters
    predictions = model.predict(df_myopia_pca)

    # Create return DataFrame with predicted clusters
    df_myopia_pca["myopic"] = model.labels_

    return df_myopia_pca

# %%
#df_myopia_pca["myopic"] = model.labels_
#df_myopia_pca.head()

# %% [markdown]
# Analyzing Clusters with the Best Value of k

# %%
clusters = get_clusters(2, df_myopia_pca)
clusters.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0               0.535503               1.145004              -1.385019
# 1              -0.624706              -1.575786              -0.794253
# 2              -0.933479              -0.717076               0.820150
# 3               0.106354               1.192475              -0.024441
# 4              -0.388503              -2.839655              -0.229767
#
#    principal component 4  principal component 5  principal component 6  \
# 0               0.116006              -3.226691              -1.928459
# 1               1.156287               0.292256               0.349060
# 2              -1.547638               0.173941               0.272783
# 3               1.507469              -2.356836              -0.023139
# 4              -0.622510               0.271458              -0.928956
#
#    principal component 7  principal component 8  principal component 9  \
# ...

# %%
def show_clusters(df_myopia_pca):
    plt.scatter(df_myopia_pca['principal component 1'], df_myopia_pca['principal component 2'], 
                c=df_myopia_pca['myopic'])
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.show()

# %%
show_clusters(clusters)

# %% [markdown]
# The data (sample) is inconclusive to determine if the patients can be clustered into whether the kids have
# or does not have myopic. There was 618 samples with 14 variables. After scaling the data and reducing the dimensions,
# the principle component was reduced to 618 sample with 2 components. If additional dimensions were added,
# the data would likely allow us to show definitive clusters to help determine whether our patients are myopic or not.
